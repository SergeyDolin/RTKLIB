# %%
import pymap3d as pm

# %%
pm.geodetic2enu(54.9871312011, 82.8649347681, 83.7120,  54.987131958,   82.864932616,    84.1256)
# Out:
# (np.float64(0.13776764479491183),
#  np.float64(-0.08426170504214281),
#  np.float64(-0.4136000011092014))
